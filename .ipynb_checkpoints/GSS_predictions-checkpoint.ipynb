# %%
## Hypothesis generator for the GSS Data:
from hypothesis import Hypothesis

import os
from quasinet import qnet
from cognet.cognet import cognet as cg
from cognet.dataFormatter import dataFormatter
from cognet.model import model 
from IPython.display import Image
from IPython.core.display import HTML

yr = '2018'
GSSDATA = 'csv_files/gss_'+yr+'.csv'
qnet_dir = 'qnets/'
outdirname = 'dotfiles/'
qnet_path = qnet_dir + 'gss_'+yr+'.joblib'

# %%
## read Qnet file and load it into Qnet model. If it doesn't exist, fit data into model and generate file.

data_obj=dataFormatter(GSSDATA)
model_obj = model()
if os.path.exists(qnet_path):
    model_obj.load(qnet_path)
else:
    model_obj.fit(data_obj = data_obj)
    model_obj.save(qnet_path)

# %%
cognet_obj = cg()


cognet_obj.load_from_model(model_obj, data_obj, 'all')
cognet_obj.dmat_filewriter("GSS_cognet.py", qnet_path,
                           MPI_SETUP_FILE="GSS_mpi_setup.sh",
                           MPI_RUN_FILE="GSS_mpi_run.sh",
                           MPI_LAUNCHER_FILE="GSS_mpi_launcher.sh",
                           YEARS='2018',NODES=4,T=14)
cognet_obj.samples
# Out:
#                wrkstat HRS1 HRS2 evwork         wrkslf     wrkgovt OCC10  \
# 0     temp not working    e    c    nan   someone else     private     b
# 1     working fulltime    c    e    nan   someone else     private     b
# 2     working fulltime    c    e    nan   someone else     private     c
# 3     working fulltime    e    e    nan   someone else     private     c
# 4     working fulltime    c    e    nan  self-employed     private     c
# ...                ...  ...  ...    ...            ...         ...   ...
# 1779           retired    e    e    yes   someone else     private     d
# 1780            school    e    e     no            nan         nan     e
# 1781  working fulltime    c    e    nan   someone else  government     c
# 1782  working parttime    c    e    nan   someone else     private     c
# 1783           retired    e    e    yes   someone else     private     c
#
#      PRESTG10 PRESTG105PLUS INDUS10  ...        neisafe             rlooks  \
# 0           c             c       c  ...      very safe                nan
# 1           d             d       c  ...      very safe                nan
# 2           d             d       c  ...      very safe         attractive
# 3           c             c       c  ...  somewhat safe      about average
# 4           c             c       c  ...    very unsafe  very unattractive
# ...       ...           ...     ...  ...            ...                ...
# 1779        c             c       c  ...      very safe                nan
# 1780        e             e       e  ...  somewhat safe      about average
# 1781        c             c       c  ...      very safe                nan
# 1782        b             b       c  ...      very safe      about average
# 1783        c             c       c  ...      very safe         attractive
#
#                  rgroomed                 rweight   rhlthend wtss wtssnr  \
# 0                     nan                     nan        nan    e      e
# 1                     nan                     nan        nan    c      c
# 2           about average  about the right weight        nan    c      c
# 3           about average    slightly underweight  excellent    c      c
# 4     very poorly groomed         very overweight       poor    c      c
# ...                   ...                     ...        ...  ...    ...
# 1779                  nan                     nan        nan    c      c
# 1780        about average    slightly underweight  excellent    d      d
# 1781                  nan                     nan        nan    c      c
# 1782        about average     slightly overweight  excellent    c      c
# 1783         well groomed  about the right weight        nan    c      c
#
#      wtssall vstrat vpsu
# 0          e   3301    1
# 1          c   3301    1
# 2          c   3301    1
# 3          c   3301    1
# 4          c   3301    1
# ...      ...    ...  ...
# 1779       c   3378    2
# 1780       d   3378    2
# 1781       c   3378    2
# 1782       c   3378    2
# 1783       c   3378    2
#
# [1784 rows x 1034 columns]

# %%
## Generating tree files

model_obj.save(qnet_path)
qnet_model = qnet.load_qnet(qnet_path)

if not os.path.exists(outdirname):
    os.mkdir(outdirname)
    
for idx, feature_name in enumerate(qnet_model.feature_names):
    qnet.export_qnet_tree(qnet_model, idx, os.path.join(outdirname, '{}.dot'.format(feature_name)), 
                          outformat = "graphviz", detailed_output = True)

! cd 'dotfiles'; for i in `ls *dot`; do dot -Tpng $i -o ${i/dot/png}; done >& /dev/null

# %%
! ls -lhS dotfiles/*png | head -n 3
## Viewing the generated tree file
Image(filename= outdirname + 'abmoral.png')
# Out:
# ls: cannot access dotfiles/*png: No such file or directory
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-9-031dd650e2b6> in <module>
#       2 dotfiles_location = 'dotfiles/'
#       3 ## Viewing the generated tree file
# ----> 4 Image(filename= dotfiles_location + 'abmoral.png')
#
# /software/python-3.8.5-el7-x86_64/lib/python3.8/site-packages/IPython/core/display.py in __init__(self, data, url, filename, format, embed, width, height, retina, unconfined, metadata)
#    1222         self.retina = retina
#    1223         self.unconfined = unconfined
# -> 1224         super(Image, self).__init__(data=data, url=url, filename=filename,
#    1225                 metadata=metadata)
#    1226
#
# /software/python-3.8.5-el7-x86_64/lib/python3.8/site-packages/IPython/core/display.py in __init__(self, data, url, filename, metadata)
#     628             self.metadata = {}
#     629
# --> 630         self.reload()
#     631         self._check_data()
#     632
#
# /software/python-3.8.5-el7-x86_64/lib/python3.8/site-packages/IPython/core/display.py in reload(self)
#    1254         """Reload the raw data from file or URL."""
#    1255         if self.embed:
# -> 1256             super(Image,self).reload()
#    1257             if self.retina:
#    1258                 self._retina_shape()
#
# /software/python-3.8.5-el7-x86_64/lib/python3.8/site-packages/IPython/core/display.py in reload(self)
#     653         """Reload the raw data from file or URL."""
#     654         if self.filename is not None:
# --> 655             with open(self.filename, self._read_flags) as f:
#     656                 self.data = f.read()
#     657         elif self.url is not None:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'dotfiles/abmoral.png'

# %%
## Generating Hypothesis

hypothesis = Hypothesis(model_path = qnet_path, detailed_labels = True,
                       no_self_loops = False)

#hypothesis.to_dot('hypothesis_GSS.dot')
hypothesis.hypotheses.sort_values('src')
# Out:
# Empty DataFrame
# Columns: [src, tgt, time_tgt, lomar, pvalue]
# Index: []
